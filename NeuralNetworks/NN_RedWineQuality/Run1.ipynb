# %% [raw]
# Import libraries ↓

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Loading and Preprocessing Data ↓

# %%
red = pd.read_csv("../CSV/redwinequality.csv", sep=';')
white = pd.read_csv("../CSV/whitewinequality.csv", sep=';')

red['type'] = 1
white['type'] = 0

wines = pd.concat([red, white], ignore_index=True)
wines.dropna(inplace=True)

# %% [markdown]
# Data splitsing (test % train sets) ↓

# %%
X = wines.drop('type', axis=1)
y = wines['type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=61)

# %% [markdown]
# Create model ↓

# %%
from keras.layers import Dense, Input
model = Sequential()

model.add(Input(shape=(12,)))
model.add(Dense(12, activation='relu'))
model.add(Dense(9, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Train model ↓

# %%
model.fit(X_train, y_train, epochs=3 ,batch_size=1, verbose=1)

# %% [markdown]
# Predictions ↓

# %%
y_pred = model.predict(X_test)

y_pred_labels = (y_pred >= 0.5).astype(int)

for prediction in y_pred_labels[:12]:
    wine_type = "Red wine" if prediction == 1 else "White wine"
    print(f"Prediction: {wine_type}")

# %% [markdown]
# Evaluatie ↓

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

accuracy = accuracy_score(y_test, y_pred_labels)
confusion = confusion_matrix(y_test, y_pred_labels)
report = classification_report(y_test, y_pred_labels)

print("Accuracy:")
print(accuracy)

print("\nConfusion Matrix:")
print(confusion)

print("\nClassification Report:")
print(report)
